# %% [markdown]
# ## Code for analysis of one patient (ID: 18992)
# Requires that certain data files are available for loading. See all .csv files in code cells below.
#
# Author: Avon Huxor
#
# Date: May 2017

# %%
import pandas as pd
#import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# 'Get idea of length of largest data file'
# 'this can take some time! so is switched to markdown for now'
# !wc -l CHARTEVENTS.csv

# %%
# !ls *.csv
# Out:
# ADMISSIONS.csv                INPUTEVENTS_CV.csv
# CALLOUT.csv                   INPUTEVENTS_MV.csv
# CAREGIVERS.csv                LABEVENTS.csv
# CHARTEVENTS.csv               MICROBIOLOGYEVENTS.csv
# CPTEVENTS.csv                 NOTEEVENTS.csv
# DATETIMEEVENTS.csv            OUTPUTEVENTS.csv
# DIAGNOSES_ICD.csv             PATIENTS.csv
# DRGCODES.csv                  PRESCRIPTIONS.csv
# D_CPT.csv                     PROCEDUREEVENTS_MV.csv
# D_ICD_DIAGNOSES.csv           PROCEDURES_ICD.csv
# D_ICD_PROCEDURES.csv          SERVICES.csv
# D_ITEMS.csv                   TRANSFERS.csv
# D_LABITEMS.csv                nba2013.csv
# ICUSTAYS.csv                  patient_18992_chartevents.csv

# %%
# load list of item code number and associated names
items_df = pd.read_csv('D_ITEMS.csv',infer_datetime_format=True)

# %%
# load small part of chartevents to get column names
# to use for labelling the subset of data for the individual patient
# as these are not available in the grepped file

chartevents_df = pd.read_csv('CHARTEVENTS.csv',infer_datetime_format=True,nrows=20)
print(chartevents_df.head(3))
col_name_list = list(chartevents_df)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0     788          36   165660      241249  223834  2134-05-12 12:00:00
# 1     789          36   165660      241249  223835  2134-05-12 12:00:00
# 2     790          36   165660      241249  224328  2134-05-12 12:00:00
#
#              STORETIME   CGID   VALUE  VALUENUM VALUEUOM  WARNING  ERROR  \
# 0  2134-05-12 13:56:00  17525   15.00     15.00    L/min        0      0
# 1  2134-05-12 13:56:00  17525  100.00    100.00      NaN        0      0
# 2  2134-05-12 12:18:00  20823    0.37      0.37      NaN        0      0
#
#    RESULTSTATUS  STOPPED
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN

# %% [markdown]
# ### This has been done already, so new data file exists
#
# The CHARTEVENTS datatable is so large that it was not possible to load the whole table into Pandas on my (AH) machine. Thus unix/grep was used to extract the data for one pataient by using the patient ID as the pattern. In this case, no false rown were captured. Short SUBJECT_ID number may generate some false rows, but these can be cleaned using the column of the Pnadas dataframe that is read in.
#
# Only run again if this file is deleted, as takes long time!!
#
# !date
#
# !grep -w '18992' CHARTEVENTS.csv > patient_18992_chartevents.csv
#
# !date

# %%
chartevents_df.head()
col_name_list = list(chartevents_df)

# %%
# read in patient 18992 data and parse dates to correct dtype
# note: this patient was chosen as he has the longest LOS for a single visit; 104 days
patient_18992_chartevents_df = pd.read_csv('patient_18992_chartevents.csv',parse_dates=[5,6])
# set column names to that from the basic csv file
patient_18992_chartevents_df.columns = col_name_list
patient_18992_chartevents_df.head()
# Out:
# /Users/ahuxor/anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID           CHARTTIME  \
# 0  131158430       18992   123291      224638      39 2124-05-05 19:00:00
# 1  131158431       18992   123291      224638      40 2124-05-05 19:00:00
# 2  131158432       18992   123291      224638      50 2124-05-05 19:00:00
# 3  131158433       18992   123291      224638      52 2124-05-05 19:00:00
# 4  131158434       18992   123291      224638      60 2124-05-05 19:00:00
#
#             STORETIME   CGID         VALUE  VALUENUM VALUEUOM  WARNING  ERROR  \
# 0 2124-05-05 18:41:00  18725        8.0 mm       NaN      NaN      NaN    NaN
# 1 2124-05-05 18:41:00  18725  Tracheostomy       NaN      NaN      NaN    NaN
# 2 2124-05-05 18:41:00  18725            20      20.0      NaN      NaN    NaN
# 3 2124-05-05 18:56:00  18386           102     102.0     mmHg      NaN    NaN
# 4 2124-05-05 18:41:00  18725          24.5      24.5    cmH2O      NaN    NaN
#
#   RESULTSTATUS   STOPPED
# 0          NaN  NotStopd
# 1          NaN  NotStopd
# 2          NaN  NotStopd
# 3          NaN  NotStopd
# 4          NaN  NotStopd

# %%
# get list of highest cadence items (parameters)
# to investigate the most observed parameters for this patient over time
pat_18992_top_items = patient_18992_chartevents_df.groupby('ITEMID').size().sort_values(ascending=False).head(20)
# display highest cadence parameters, as ITEMID, with number of occurances
pat_18992_top_items
# Out:
# ITEMID
# 646     2757
# 211     2572
# 128     2556
# 550     2556
# 742     2556
# 1484    2552
# 618     2541
# 1125    2525
# 212     2489
# 161     2481
# 5820    2094
# 5819    2094
# 5815    2093
# 8553    2089
# 8554    2089
# 8549    2088
# 159     1854
# 51      1730
# 8368    1728
# 52      1726
# dtype: int64

# %%
# check labels of the high cadence parameters for this patient
# displays:
# ITEMID
# row_number, label
for item in pat_18992_top_items.index:
    print(item)
    print(items_df[items_df.ITEMID==item].LABEL)
# Out:
# 646
# 1418    SpO2
# Name: LABEL, dtype: object
# 211
# 475    Heart Rate
# Name: LABEL, dtype: object
# 128
# 394    Code Status
# Name: LABEL, dtype: object
# 550
# 195    Precautions
# Name: LABEL, dtype: object
# 742
# 1505    calprevflg
# Name: LABEL, dtype: object
# 1484
# 2755    Risk for Falls
# Name: LABEL, dtype: object
# 618
# 263    Respiratory Rate
# Name: LABEL, dtype: object
# 1125
# 118    Service Type
# Name: LABEL, dtype: object
# 212
# 476    Heart Rhythm
# Name: LABEL, dtype: object
# 161
# 425    Ectopy Type
# Name: LABEL, dtype: object
# 5820
# 2469    SpO2 Alarm [Low]
# Name: LABEL, dtype: object
# 5819
# 2468    Resp Alarm [Low]
# Name: LABEL, dtype: object
# 5815
# 2464    HR Alarm [Low]
# Name: LABEL, dtype: object
# 8553
# 4803    Resp Alarm [High]
# Name: LABEL, dtype: object
# 8554
# 4804    SpO2 Alarm [High]
# Name: LABEL, dtype: object
# 8549
# 4799    HR Alarm [High]
# Name: LABEL, dtype: object
# 159
# 423    Ectopy Frequency
# Name: LABEL, dtype: object
# 51
# 320    Arterial BP [Systolic]
# Name: LABEL, dtype: object
# 8368
# 4637    Arterial BP [Diastolic]
# Name: LABEL, dtype: object
# 52
# 321    Arterial BP Mean
# Name: LABEL, dtype: object

# %%
items_df.dtypes
temp_items = items_df[items_df.LABEL.notnull()]
blood_pressure_items = temp_items[temp_items.LABEL.str.contains('BP')]
blood_pressure_items
# Out:
#        ROW_ID  ITEMID                             LABEL  \
# 271         8    1449                  Arterial BP(Rad)
# 293        30       4              ABI Ankle BP [Right]
# 294        31       5           ABI Brachial BP [Right]
# 295        32       6                    ABP [Systolic]
# 320        57      51            Arterial BP [Systolic]
# 321        58      52                  Arterial BP Mean
# 332        69      63                       BIPAP - BPM
# 419       156     155                        Doppler BP
# 485       222     224                         IABP Mean
# 486       223     225                      IABP setting
# 671       408     442              Manual BP [Systolic]
# 672       409     443              Manual BP Mean(calc)
# 682       419     455                    NBP [Systolic]
# 683       420     456                          NBP Mean
# 705       442     480   Orthostat BP sitting [Systolic]
# 707       444     482   OrthostatBP standing [Systolic]
# 709       446     484   Orthostatic BP lying [Systolic]
# 1699      880    3241                           LFEMABP
# 1710      891    3256                       L ulnar ABP
# 1746      927    3311                    BP Alarm [Low]
# 1747      928    3312                    BP Cuff [Mean]
# 1748      929    3313                BP Cuff [Systolic]
# 1749      930    3314                BP Left Arm [Mean]
# 1750      931    3315            BP Left Arm [Systolic]
# 1751      932    3316                BP Left Leg [Mean]
# 1752      933    3317            BP Left Leg [Systolic]
# 1753      934    3318                     BP PAL [Mean]
# 1754      935    3319                 BP PAL [Systolic]
# 1755      936    3320               BP Right Arm [Mean]
# 1756      937    3321           BP Right Arm [Systolic]
# ...       ...     ...                               ...
# 10161   13107  224315                 ABI Brachial BP L
# 10162   13108  224317                    ABI Ankle BP R
# 10163   13109  224318          ABI Ankle BP L (Impella)
# 10164   13110  224322                         IABP Mean
# 10477   14204  225778                IABP Dressing Type
# 10761   14154  225727            IABP Line Tip Cultured
# 10776   14169  225742            IABP Line Discontinued
# 10870   15089  228005  PBP (Prefilter) Replacement Rate
# 11153   14228  225979                         IABP Size
# 11154   14229  225980                       IABP Volume
# 11155   14230  225981             IABP Alarms Activated
# 11156   14231  225982             IABP Balloon Waveform
# 11157   14232  225984                      IABP Trigger
# 11158   14233  225985                IABP Helium Tubing
# 11159   14234  225986     IABP Arterial Waveform Source
# 11324   13425  224645             Orthostatic BPs lying
# 11325   13426  224646           Orthostatic BPs sitting
# 11337   14235  225987                 IABP Power Source
# 11338   14236  225988              IABP Position on leg
# 11345   14243  226096          Orthostatic BPd standing
# 11351   14249  226110   IABP placed in outside facility
# 11653   14353  226092             Orthostatic BPd lying
# 11654   14354  226094           Orthostatic BPd sitting
# 12016   15334  228145                    ABI Ankle BP L
# 12017   15335  228146                 ABI Brachial BP R
# 12179   12144   45409                         SC32 w/BP
# 12371   12762  223766          Orthostatic BPs standing
# 12443   13687  225309                   ART BP Systolic
# 12444   13688  225310                  ART BP Diastolic
# 12445   13689  225312                       ART BP mean
#
#                            ABBREVIATION    DBSOURCE         LINKSTO  \
# 271                                 NaN     carevue     chartevents
# 293                                 NaN     carevue     chartevents
# 294                                 NaN     carevue     chartevents
# 295                                 NaN     carevue     chartevents
# 320                                 NaN     carevue     chartevents
# 321                                 NaN     carevue     chartevents
# 332                                 NaN     carevue     chartevents
# 419                                 NaN     carevue     chartevents
# 485                                 NaN     carevue     chartevents
# 486                                 NaN     carevue     chartevents
# 671                                 NaN     carevue     chartevents
# 672                                 NaN     carevue     chartevents
# 682                                 NaN     carevue     chartevents
# 683                                 NaN     carevue     chartevents
# 705                                 NaN     carevue     chartevents
# 707                                 NaN     carevue     chartevents
# 709                                 NaN     carevue     chartevents
# 1699                                NaN     carevue     chartevents
# 1710                                NaN     carevue     chartevents
# 1746                                NaN     carevue     chartevents
# 1747                                NaN     carevue     chartevents
# 1748                                NaN     carevue     chartevents
# 1749                                NaN     carevue     chartevents
# 1750                                NaN     carevue     chartevents
# 1751                                NaN     carevue     chartevents
# 1752                                NaN     carevue     chartevents
# 1753                                NaN     carevue     chartevents
# 1754                                NaN     carevue     chartevents
# 1755                                NaN     carevue     chartevents
# 1756                                NaN     carevue     chartevents
# ...                                 ...         ...             ...
# 10161                 ABI Brachial BP L  metavision     chartevents
# 10162                    ABI Ankle BP R  metavision     chartevents
# 10163          ABI Ankle BP L (Impella)  metavision     chartevents
# 10164                    MAP - Assisted  metavision     chartevents
# 10477                IABP Dressing Type  metavision     chartevents
# 10761            IABP Line Tip Cultured  metavision     chartevents
# 10776            IABP Line Discontinued  metavision     chartevents
# 10870  PBP (Prefilter) Replacement Rate  metavision     chartevents
# 11153                         IABP Size  metavision     chartevents
# 11154                       IABP Volume  metavision     chartevents
# 11155             IABP Alarms Activated  metavision     chartevents
# 11156             IABP Balloon Waveform  metavision     chartevents
# 11157                      IABP Trigger  metavision     chartevents
# 11158                IABP Helium Tubing  metavision     chartevents
# 11159     IABP Arterial Waveform Source  metavision     chartevents
# 11324             Orthostatic BPs lying  metavision     chartevents
# 11325           Orthostatic BPs sitting  metavision     chartevents
# 11337                 IABP Power Source  metavision     chartevents
# 11338              IABP Position on leg  metavision     chartevents
# 11345          Orthostatic BPd standing  metavision     chartevents
# 11351   IABP placed in outside facility  metavision     chartevents
# 11653             Orthostatic BPd lying  metavision     chartevents
# 11654           Orthostatic BPd sitting  metavision     chartevents
# 12016                   ABI Ankle BP L   metavision     chartevents
# 12017                ABI Brachial BP R   metavision     chartevents
# 12179                               NaN     carevue  inputevents_cv
# 12371          Orthostatic BPs standing  metavision     chartevents
# 12443                   ART BP Systolic  metavision     chartevents
# 12444                  ART BP Diastolic  metavision     chartevents
# 12445                       ART BP mean  metavision     chartevents
#
#                       CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 271                        NaN      NaN        NaN        NaN
# 293                        NaN      NaN        NaN        NaN
# 294                        NaN      NaN        NaN        NaN
# 295                        NaN      NaN        NaN        NaN
# 320                        NaN      NaN        NaN        NaN
# 321                        NaN      NaN        NaN        NaN
# 332                        NaN      NaN        NaN        NaN
# 419                        NaN      NaN        NaN        NaN
# 485                        NaN      NaN        NaN        NaN
# 486                        NaN      NaN        NaN        NaN
# 671                        NaN      NaN        NaN        NaN
# 672                        NaN      NaN        NaN        NaN
# 682                        NaN      NaN        NaN        NaN
# 683                        NaN      NaN        NaN        NaN
# 705                        NaN      NaN        NaN        NaN
# 707                        NaN      NaN        NaN        NaN
# 709                        NaN      NaN        NaN        NaN
# 1699                       NaN      NaN        NaN        NaN
# 1710                       NaN      NaN        NaN        NaN
# 1746                       NaN      NaN        NaN        NaN
# 1747                       NaN      NaN        NaN        NaN
# 1748                       NaN      NaN        NaN        NaN
# 1749                       NaN      NaN        NaN        NaN
# 1750                       NaN      NaN        NaN        NaN
# 1751                       NaN      NaN        NaN        NaN
# 1752                       NaN      NaN        NaN        NaN
# 1753                       NaN      NaN        NaN        NaN
# 1754                       NaN      NaN        NaN        NaN
# 1755                       NaN      NaN        NaN        NaN
# 1756                       NaN      NaN        NaN        NaN
# ...                        ...      ...        ...        ...
# 10161                     IABP     mmHg    Numeric        NaN
# 10162                     IABP     mmHg    Numeric        NaN
# 10163                  Impella     mmHg    Numeric        NaN
# 10164                     IABP     mmHg    Numeric        NaN
# 10477  Access Lines - Invasive      NaN       Text        NaN
# 10761  Access Lines - Invasive      NaN   Checkbox        NaN
# 10776  Access Lines - Invasive      NaN       Text        NaN
# 10870                 Dialysis    ml/hr    Numeric        NaN
# 11153  Access Lines - Invasive      NaN       Text        NaN
# 11154  Access Lines - Invasive       mL    Numeric        NaN
# 11155  Access Lines - Invasive      NaN   Checkbox        NaN
# 11156  Access Lines - Invasive      NaN       Text        NaN
# 11157  Access Lines - Invasive      NaN       Text        NaN
# 11158  Access Lines - Invasive      NaN       Text        NaN
# 11159  Access Lines - Invasive      NaN       Text        NaN
# 11324      Routine Vital Signs     mmHg    Numeric        NaN
# 11325      Routine Vital Signs     mmHg    Numeric        NaN
# 11337  Access Lines - Invasive      NaN       Text        NaN
# 11338  Access Lines - Invasive      NaN       Text        NaN
# 11345      Routine Vital Signs     mmHg    Numeric        NaN
# 11351  Access Lines - Invasive      NaN   Checkbox        NaN
# 11653      Routine Vital Signs     mmHg    Numeric        NaN
# 11654      Routine Vital Signs     mmHg    Numeric        NaN
# 12016                     IABP     mmHg    Numeric        NaN
# 12017                     IABP     mmHg    Numeric        NaN
# 12179         Free Form Intake      NaN        NaN        NaN
# 12371      Routine Vital Signs     mmHg    Numeric        NaN
# 12443      Routine Vital Signs     mmHg    Numeric        NaN
# 12444      Routine Vital Signs     mmHg    Numeric        NaN
# 12445      Routine Vital Signs     mmHg    Numeric        NaN
#
# [151 rows x 10 columns]

# %%
items_df[items_df.ITEMID==52]
# Out:
#      ROW_ID  ITEMID             LABEL ABBREVIATION DBSOURCE      LINKSTO  \
# 321      58      52  Arterial BP Mean          NaN  carevue  chartevents
#
#     CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 321      NaN      NaN        NaN        NaN

# %%
# get chart data for 52 = mean arterial blood pressure for this long-term patient, carevue
patient_18992_item52_df = patient_18992_chartevents_df[patient_18992_chartevents_df.ITEMID==52]

# %%
# get chart data for 456 = mean NBP (noninvasive blood pressure)for this long-term patient, carevue
patient_18992_item456_df = patient_18992_chartevents_df[patient_18992_chartevents_df.ITEMID==456]
len(patient_18992_item456_df)
# Out:
# 987

# %%
# get chart data for 224322 = 
patient_18992_item224322_df = patient_18992_chartevents_df[patient_18992_chartevents_df.ITEMID==224322]
len(patient_18992_item224322_df)
# Out:
# 0

# %%
# look at chart data for 220052 = mean blood pressure for this long-term patient, metavision
# there is no metavision mean blood pressure for this patient
patient_18992_item220052_df = patient_18992_chartevents_df[patient_18992_chartevents_df.ITEMID==220052]
len(patient_18992_item220052_df)
# Out:
# 0

# %%
# get chart data for 220181 = non invasive mean blood pressure for this long-term patient, metavision
# equally there is no data from mtavision taken by non-invasive means
patient_18992_item220181_df = patient_18992_chartevents_df[patient_18992_chartevents_df.ITEMID==220181]
len(patient_18992_item220181_df)
# Out:
# 0

# %%
bp_item_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-791320287adb> in <module>()
# ----> 1 bp_item_list
#
# NameError: name 'bp_item_list' is not defined

# %%
patient_18992_item220181_df

# %%
# some high peaks but as '52' is carevue than no error

fig = patient_18992_item52_df.plot('CHARTTIME','VALUENUM',color='g')
fig.set_ylabel('MAP (mm/Hg)')
fig.set_xlabel('Time')
fig.legend_.remove()
plt.savefig("patient18992_MAP_carevue_plot.pdf", bbox_inches = 'tight',
    pad_inches = 0.1)

# there are gaps in plot suggesting Metavision may have been used for some parts of visit

# %%
patient_18992_item52_df_sorted = patient_18992_item52_df.sort_values('CHARTTIME')

# %%
# add itemid '456' 

fig = patient_18992_item456_df.plot('CHARTTIME','VALUENUM',figsize=(15, 6))
fig.plot(patient_18992_item52_df_sorted['CHARTTIME'],patient_18992_item52_df_sorted['VALUENUM'])
fig.set_ylabel('NBP (mm/Hg)')
fig.set_xlabel('Time')
fig.legend_.remove()
plt.savefig("patient18992_MAP_NBP_plot.pdf", bbox_inches = 'tight',
    pad_inches = 0.1)

# there are gaps in plot suggesting Metavision may have been used for some parts of visit

# %%
# when do the excessive peaks occur (note that there is no error flag for carevue)?
# get values for plotting a zoomed in version
patient_18992_item52_df[patient_18992_item52_df.VALUENUM >200]

# %%
# zoom into to this region

fig = patient_18992_item456_df.plot('CHARTTIME','VALUENUM',ylim=[0,300],xlim=['2124-05-27','2124-06-07'],figsize=(15, 6))
fig.plot(patient_18992_item52_df_sorted['CHARTTIME'],patient_18992_item52_df_sorted['VALUENUM'])
fig.set_ylabel('MAP & NBP (mm/Hg)')
fig.set_xlabel('Time')
fig.legend_.remove()
plt.savefig("patient18992_MAP_NBP_plot_zoomed.pdf", bbox_inches = 'tight',
    pad_inches = 0.1)
